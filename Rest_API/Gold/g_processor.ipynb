# %%
# %run /Users/ratnakar.eethakota@diggibyte.com/Rest_API/Silver_API/s_common_function

# %%
# %run /Users/ratnakar.eethakota@diggibyte.com/Rest_API/Gold_API/g_common_function

# %%
df1=df_target()

# %%
list_url=['Turkey','United States','Jordan','United Kingdom','Egypt']
for x in list_url:
    df1=get_dat_api(f'http://universities.hipolabs.com/search?country={x}',df1)

# %%
df3=droping_col(df1,col_name="state_province")

# %%
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df5=country_count(df3,colname="country")
display(df5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>count</th></tr></thead><tbody><tr><td>Turkey</td><td>182</td></tr><tr><td>United States</td><td>2287</td></tr><tr><td>Jordan</td><td>29</td></tr><tr><td>United Kingdom</td><td>185</td></tr><tr><td>Egypt</td><td>44</td></tr></tbody></table></div>

# %%
df6=name_count(df3,col_na="name")

# %%
display(df6)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
