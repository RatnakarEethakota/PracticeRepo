# %%
# %run /Users/ratnakar.eethakota@diggibyte.com/Rest_API/Bronze_API/b_common_function

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.types import StructType, StructField, StringType, ArrayType
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
def droping_col(df1,col_name):
    return df1.drop(col_name)

# %%
def write_mode(df1,formatname,mode,name):
    df1.write.format(formatname).mode(mode).saveAsTable(name)
