# %%
# %run /Users/ratnakar.eethakota@diggibyte.com/Rest_API/Bronze_API/b_common_function

# %%
df1=df_target()

# %%
list_url=['Turkey','United States','Jordan','United Kingdom','Egypt']
for x in list_url:
    df1=get_dat_api(f'http://universities.hipolabs.com/search?country={x}',df1)

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# format_name="json"
# path="/FileStore/api_bronze"

# %%
writing_df(df2,format_name,path)
