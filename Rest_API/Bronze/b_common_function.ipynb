# %%
# %run /Users/ratnakar.eethakota@diggibyte.com/Rest_API/Bronze_API/b_schema

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.types import StructType, StructField, StringType, ArrayType
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
def df_target():
    return spark.createDataFrame([],schema)

# %%
def get_dat_api(path,df_target):
    response = requests.get(path)
    df = spark.createDataFrame(response.json(), schema)
    return df_target.union(df)

# %%
def data():
    empty=spark.createDataFrame([],schema)
    for x in l:
        response = requests.get(path)
        df = spark.createDataFrame(response.json(), schema)

# %%
# def writing_df(df2,format_name,path):
#     df2.write.format("json").save(path)
